# %% [markdown]
# # Exercise 1.41

# %%
#lang iracket/lang #:require sicp
(#%require "../../libraries/chapter-01.rkt")

# %%
(define (double f)
  (lambda (x)
    (f (f x))))

# %%
((double inc) 5)
# Out:
# 7

# %%
(((double (double double)) inc) 5)
# Out:
# 21
