# %% [markdown]
# # Exercise 1.41

# %%
#lang iracket/lang #:require sicp
(#%require sicp-libraries/chapter-01)

# %%
(define (double f)
  (lambda (x)
    (f (f x))))

# %%
((double inc) 5)
# Out:
# 7

# %%
(((double (double double)) inc) 5)
# Out:
# 21
