# %% [markdown]
# # Exercise 1.42

# %%
#lang iracket/lang #:require sicp
(#%require "../../libraries/chapter-01.rkt")

# %%
(define (compose f g)
  (lambda (x)
    (f (g x))))

# %%
((compose square inc) 6)
# Out:
# 49
