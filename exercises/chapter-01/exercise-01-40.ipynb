# %% [markdown]
# # Exercise 1.40

# %%
#lang iracket/lang #:require sicp
(#%require "../../libraries/chapter-01.rkt")

# %%
(define (cubic a b c)
  (lambda (x)
    (+ (cube x)
       (* a (square x))
       (* b x)
       c)))

# %%
(newtons-method (cubic 1 2 3) 1)
# Out:
# -1.2756822036498454
