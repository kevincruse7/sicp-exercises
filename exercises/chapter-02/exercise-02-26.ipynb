# %% [markdown]
# # Exercise 2.26

# %%
#lang iracket/lang #:require sicp
(#%require sicp-libraries/chapter-02)

# %%
(define x (list 1 2 3))
(define y (list 4 5 6))

# %%
(display (append x y))
# Out:
# (1 2 3 4 5 6)

# %%
(display (cons x y))
# Out:
# ((1 2 3) 4 5 6)

# %%
(display (list x y))
# Out:
# ((1 2 3) (4 5 6))
