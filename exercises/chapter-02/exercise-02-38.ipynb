# %% [markdown]
# # Exercise 2.38

# %%
#lang iracket/lang #:require sicp
(#%require sicp-libraries/chapter-02)

# %%
(define (fold-left op initial sequence)
  (define (iter result rest)
    (if (null? rest)
        result
        (iter (op result (car rest))
              (cdr rest))))
  (iter initial sequence))

# %%
(accumulate / 1 (list 1 2 3))
# Out:
# 3/2

# %%
(fold-left / 1 (list 1 2 3))
# Out:
# 1/6

# %%
(display (accumulate list nil (list 1 2 3)))
# Out:
# (1 (2 (3 ())))

# %%
(display (fold-left list nil (list 1 2 3)))
# Out:
# (((() 1) 2) 3)

# %% [markdown]
# For `fold-right` and `fold-left` to produce the same result, `op` should exhibit the commutative property.
