# %% [markdown]
# # Exercise 2.47

# %%
#lang iracket/lang #:require sicp
(#%require sicp-libraries/chapter-02)

# %%
(define (make-frame origin edge1 edge2)
  (list origin edge1 edge2))

(define (origin-frame frame)
  (car frame))

(define (edge1-frame frame)
  (cadr frame))

(define (edge2-frame frame)
  (caddr frame))

(define frame (make-frame (make-vect 1 1)
                          (make-vect 2 2)
                          (make-vect 3 3)))

(display (origin-frame frame))
(newline)
(display (edge1-frame frame))
(newline)
(display (edge2-frame frame))
# Out:
# #(struct:vect 1 1)
# #(struct:vect 2 2)
# #(struct:vect 3 3)

# %%
(define (make-frame origin edge1 edge2)
  (cons origin (cons edge1 edge2)))

(define (origin-frame frame)
  (car frame))

(define (edge1-frame frame)
  (cadr frame))

(define (edge2-frame frame)
  (cddr frame))

(define frame (make-frame (make-vect 1 1)
                          (make-vect 2 2)
                          (make-vect 3 3)))

(display (origin-frame frame))
(newline)
(display (edge1-frame frame))
(newline)
(display (edge2-frame frame))
# Out:
# #(struct:vect 1 1)
# #(struct:vect 2 2)
# #(struct:vect 3 3)
